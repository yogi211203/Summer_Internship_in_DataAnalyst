# %% [markdown]
# # <h1><center>**`Statistics Behind Plots`**</center></h1>

# %% [markdown]
# ![](https://miro.medium.com/max/9450/1*OAFEIg9w1XHyZk0xBud14A.png)

# %% [markdown]
# # **`Univariate Plots`**
#
# The term univariate analysis refers to the analysis of one variable. You can remember this because the prefix “uni” means “one.”
# The purpose of univariate analysis is to understand the distribution of values for a single variable.

# %% [markdown]
# ## **`1. Histogram`**
#
# A histogram is one type of a graph and they are basically used to represent the data in the graph forms. It is actually one of the best methods to represent the numerical data distribution. In histogram, the x axis represents the bin ranges and the y axis represents the information about the frequency of the data.

# %% [markdown]
# ![](https://www.sharpsightlabs.com/wp-content/uploads/2019/12/histogram-explanation_v1.png)

# %% [markdown]
# ### **`Histogram Case Study`**
# ![unnamed-chunk-1-1.png](data:image/png;base64,...)

# %% [markdown]
# Here is an example showing the distribution of the night price of Rbnb appartements in the south of France. Price range is divided per 10 euros interval. For example, there are slightly less than 750 appartements with a night price between 100 and 110 euros.

# %% [markdown]
# #### **`When to use histogram ?`**
#
# Histograms are good for showing general distributional features of dataset variables. You can see roughly where the peaks of the distribution are, whether the distribution is skewed or symmetric, and if there are any outliers.

# %% [markdown]
# **`Check this link for histogram`**
# 1. https://seaborn.pydata.org/generated/seaborn.histplot.html
# 2. https://statistics.laerd.com/statistical-guides/understanding-histograms.php

# %% [markdown]
# ## **`2. Boxplot`**
#
# Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into three quartiles. This image below represents the minimum, maximum, median, first quartile and third quartile in the data set. It is also useful in comparing the distribution of data across data sets by drawing boxplots for each of them.

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/1600/1*2c21SkzJMf3frPXPAR_gZA.png)

# %% [markdown]
# #### **`In other words a Box Plot is the visual representation of the statistical five number summary of a given data set.`**
#
# A Five Number Summary includes:
#
# - Minimum
# - First Quartile
# - Median (Second Quartile)
# - Third Quartile
# - Maximum

# %% [markdown]
# ![](https://chartio.com/images/tutorials/box-plot/boxplot1.png)

# %% [markdown]
# ### **`Boxplot Case Study`**
# ![download (2).png](data:image/png;base64,...)

# %% [markdown]
# **`Check this link for boxplot`**
# 1. https://seaborn.pydata.org/generated/seaborn.boxplot.html
# 2. https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/box-plot-review

# %% [markdown]
# ## **`3. Pie Chart`**
#
# A pie chart is a circle divided into sectors that each represent a proportion of the whole. It is often used to show percentage, where the sum of the sectors equals 100%. They are often used to represent sample data—with data points belonging to a combination of different categories. Each of these categories is represented as a “slice of the pie.” The size of each slice is directly proportional to the number of data points that belong to a particular category.

# %% [markdown]
# ![PieChart-01.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# ### **`Pie Chart Case Study`**
#
# ![pie1.png](data:image/png;base64,...)

# %% [markdown]
# **`Check this link for pie plot`**
# 1. https://matplotlib.org/stable/plot_types/stats/pie.html

# %% [markdown]
# # **`Bivariate Plots`**
#
# Bivariate analysis is one of the statistical analysis where two variables are observed. One variable here is dependent while the other is independent. These variables are usually denoted by X and Y. So, here we analyse the changes occured between the two variables and to what extent.

# %% [markdown]
# ## **`1. Barplots`**
#
# In seaborn library, a barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean. It can also be understood as a visualization of the group by action. To use this plot we choose a categorical column for the x-axis and a numerical column for the y-axis, and we see that it creates a plot taking a mean per categorical column.

# %% [markdown]
# ![](https://chartio.com/assets/592d98/tutorials/charts/bar-charts/e49026506e352b4c07c4e3623b16e0229362de48bff198fe42d64c5f527bd034/bar-chart-example-1.png)![IMG_0177.png](data:image/png;base64,...)

# %% [markdown]
# This example bar chart depicts the number of purchases made on a site by different types of users. The categorical feature, user type, is plotted on the horizontal axis, and each bar’s height corresponds to the number of purchases made under each user type. We can see from this chart that while there are about three times as many purchases from new users who create user accounts than those that do not create user accounts (guests), both are dwarfed by the number of purchases made by repeating users.

# %% [markdown]
# **`Check this link for barplot`**
# 1. https://seaborn.pydata.org/generated/seaborn.barplot.html
# 2. https://www.jmp.com/en_nl/statistics-knowledge-portal/exploratory-data-analysis/bar-chart.html#:~:text=Bar%20charts%20show%20the%20frequency%20counts%20of%20data&text=Sometimes%2C%20bar%20charts%20show%20other,responses%20to%20a%20survey%20question.&text=The%20bars%20show%20the%20levels,of%20responses%20for%20that%20level.

# %% [markdown]
# ### **`Bar Plot vs Histogram`**
#
# ![](https://keydifferences.com/wp-content/uploads/2016/04/bar-graph-vs-vs-histogram-thumbnail.jpg)

# %% [markdown]
# ## **`2. Scatterplot`**
#
# A scatter plot is a type of data visualization that shows the relationship between different variables. This data is shown by placing various data points between an x- and y-axis. Scatter plots can also be known as scatter diagrams or x-y graphs, and the point of using one of these is to determine if there are patterns or correlations between two variables.
#
# **`When to use`**: Use a scatter plot to determine whether or not two variables have a relationship or correlation.
#
# **`When not to use`**: Avoid a scatter plot when your data is not at all related or you have too large dataset. (For data sets with hun‐
# dreds of thousands or millions of records, a scatterplot will be too dense, so we need a different way to visualize the relationship.)

# %% [markdown]
# ### **`Scatterplot Case Study`**
#
# ![IMG_0178.png](data:image/png;base64,...)

# %% [markdown]
# The example scatter plot above shows the diameters and heights for a sample of fictional trees. Each dot represents a single tree; each point’s horizontal position indicates that tree’s diameter (in centimeters) and the vertical position indicates that tree’s height (in meters). From the plot, we can see a generally tight positive correlation between a tree’s diameter and its height. We can also observe an outlier point, a tree that has a much larger diameter than the others. This tree appears fairly short for its girth, which might warrant further investigation.

# %% [markdown]
# **`Check this link for scatterplot`**
# 1. https://seaborn.pydata.org/generated/seaborn.scatterplot.html
# 2. https://www.khanacademy.org/math/statistics-probability/describing-relationships-quantitative-data/introduction-to-scatterplots/a/scatterplots-and-correlation-review

# %% [markdown]
# ## **`3. Line Plot`**
#
# A line chart (aka line plot, line graph) uses points connected by line segments from left to right to demonstrate changes in value. The horizontal axis depicts a continuous progression, often that of time, while the vertical axis reports values for a metric of interest across that progression.

# %% [markdown]
# ![IMG_0179.png](data:image/png;base64,...)

# %% [markdown]
# The line chart above shows the exchange rate between two fictional currencies over a six month period. As time progresses from left to right, points connect the daily exchange rates. We can read from the general slope of the line and its vertical positions that the rate improved from about 0.75 to 0.78 between March and early April, then fell gradually to about 0.765 in late May and June.

# %% [markdown]
# **`Check this link for lineplot`**
# 1. https://seaborn.pydata.org/generated/seaborn.lineplot.html
# 2. https://statisticsbyjim.com/graphs/line-charts/
