# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **`Multivariate Plots`**
#
# Multivariate analysis (MVA) is a Statistical procedure for analysis of data involving more than one type of measurement or observation. It may also mean solving problems where more than one dependent variable is analyzed simultaneously with other variables.

# %% [markdown]
# ## **`1. Stacked Bar Plot`**
#
# A stacked chart is a form of bar chart that shows the composition and comparison of a few variables, either relative or absolute, over time. Also called a stacked bar or column chart, they look like a series of columns or bars that are stacked on top of each other.

# %% [markdown]
# ### **`Stacked Chart Case Study`**
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ## **`2. Multiple Scatterplot`**
#
# A 3D scatter plot allows the visualization of multivariate data. This scatter plot takes multiple scalar variables and uses them for different axes in phase space. The different variables are combined to form coordinates in the phase space and they are displayed using glyphs and coloured using another scalar variable.

# %% [markdown]
# ### **`Scatterplot Case Study`**
#
# ![Specify_colors_scatter_plot_Seaborn_Python_1.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **`3. Multiple Lineplot`**
#
# A multiplot is a special type of plot that displays multiple Y fields over a single X field.
#
# **X field**. From the data, select the field to display on the horizontal x axis.
#
# **Y fields**. Select one or more fields from the data to display over the range of X field values.

# %% [markdown]
# ### **`Lineplot Case Study`**
#
# ![4wpmu.gif](data:image/gif;base64,...)

# %% [markdown]
# # **Bonus Advanced Charts**
#
# 1. Donut Chart
# 2.   Treemap
# 3. Background Map

# %%
import matplotlib.pyplot as plt
from palettable.colorbrewer.qualitative import Pastel1_7

# create data
names = ['groupA', 'groupB', 'groupC', 'groupD']
size = [12,11,3,30]

# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

from palettable.colorbrewer.qualitative import Pastel1_7
plt.pie(size, labels=names, colors=Pastel1_7.hex_colors)
p = plt.gcf()
p.gca().add_artist(my_circle)

# Show the graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-7f1a98d186d8> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 from palettable.colorbrewer.qualitative import Pastel1_7
#       3
#       4 # create data
#       5 names = ['groupA', 'groupB', 'groupC', 'groupD']
#
# ModuleNotFoundError: No module named 'palettable'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# # libraries
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
import pandas as pd

# Create a data frame with sample data
df = pd.DataFrame({'nb_people':[8,3,4,2], 'group':["group A", "group B", "group C", "group D"] })

# plot it
squarify.plot(sizes=df['nb_people'], label=df['group'], alpha=.8 )
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-69fda8e3bcc6> in <cell line: 3>()
#       1 # # libraries
#       2 import matplotlib.pyplot as plt
# ----> 3 import squarify    # pip install squarify (algorithm for treemap)
#       4 import pandas as pd
#       5
#
# ModuleNotFoundError: No module named 'squarify'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Import the pandas library
import pandas as pd

# Make a data frame with dots to show on the map
data = pd.DataFrame({
   'lon':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lat':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador'],
   'value':[10, 12, 40, 70, 23, 43, 100, 43]
}, dtype=str)

data
# Out:
#       lon     lat            name value
# 0     -58     -34    Buenos Aires    10
# 1       2      49           Paris    12
# 2     145     -38       melbourne    40
# 3   30.32   59.93  St Petersbourg    70
# 4   -4.03    5.33         Abidjan    23
# 5  -73.57   45.52        Montreal    43
# 6   36.82   -1.29         Nairobi   100
# 7   -38.5  -12.97        Salvador    43

# %%
# import the library
import folium

# Make an empty map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57d2699ad2dc207ec3832312125246f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57d2699ad2dc207ec3832312125246f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57d2699ad2dc207ec3832312125246f5 = L.map(
#                 &quot;map_57d2699ad2dc207ec3832312125246f5&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_991cec3e76ef9842c1edc4da44fddbca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0,len(data)):
   folium.Marker(
      location=[data.iloc[i]['lat'], data.iloc[i]['lon']],
      popup=data.iloc[i]['name'],
   ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57d2699ad2dc207ec3832312125246f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57d2699ad2dc207ec3832312125246f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57d2699ad2dc207ec3832312125246f5 = L.map(
#                 &quot;map_57d2699ad2dc207ec3832312125246f5&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_991cec3e76ef9842c1edc4da44fddbca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
#
#
#             var marker_338415358f94f7630506bc7d0289b26c = L.marker(
#                 [-34.0, -58.0],
#                 {}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
#
#
#         var popup_9a7740d6d387b031dbb546f5f03e2038 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3d25983aea06e303d650f5924967b96 = $(`&lt;div id=&quot;html_a3d25983aea06e303d650f5924967b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buenos Aires&lt;/div&gt;`)[0];
#                 popup_9a7740d6d387b031dbb546f5f03e2038.setContent(html_a3d25983aea06e303d650f5924967b96);
#
#
#
#         marker_338415358f94f7630506bc7d0289b26c.bindPopup(popup_9a7740d6d387b031dbb546f5f03e2038)
#         ;
#
#
#
#
#             var marker_dfc8993a4ed2c6009509da79daa9e46d = L.marker(
#                 [49.0, 2.0],
#                 {}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
#
#
#         var popup_7d657d24c6d4b8aad9493d9ae30081a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e24430d06b782336f5390932ad8d8932 = $(`&lt;div id=&quot;html_e24430d06b782336f5390932ad8d8932&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris&lt;/div&gt;`)[0];
#                 popup_7d657d24c6d4b8aad9493d9ae30081a7.setContent(html_e24430d06b782336f5390932ad8d8932);
#
#
#
#         marker_dfc8993a4ed2c6009509da79daa9e46d.bindPopup(popup_7d657d24c6d4b8aad9493d9ae30081a7)
#         ;
#
#
#
#
#             var marker_cc4c158947e8ad994bac30c5e8c028b0 = L.marker(
#                 [-38.0, 145.0],
#                 {}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
#
#
#         var popup_8e6401f1799b117f65cb49ff5f15dee5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e7deef57b2ec85033f9b3bdf57d5beb = $(`&lt;div id=&quot;html_1e7deef57b2ec85033f9b3bdf57d5beb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;melbourne&lt;/div&gt;`)[0];
#                 popup_8e6401f1799b117f65cb49ff5f15dee5.setContent(html_1e7deef57b2ec85033f9b3bdf57d5beb);
#
#
#
#         marker_cc4c158947e8ad994bac30c5e8c028b0.bindPopup(popup_8e6401f1799b117f65cb49ff5f15dee5)
#         ;
#
#
#
#
#             var marker_d0e947979d024a8f5967e57c6335a5ba = L.marker(
#                 [59.93, 30.32],
#                 {}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
#
#
#         var popup_9cb55d5ef88cc3c482f21819d4568909 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19bfd993928936189ead343201506b20 = $(`&lt;div id=&quot;html_19bfd993928936189ead343201506b20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Petersbourg&lt;/div&gt;`)[0];
#                 popup_9cb55d5ef88cc3c482f21819d4568909.setContent(html_19bfd993928936189ead343201506b20);
#
#
#
#         marker_d0e947979d024a8f5967e57c6335a5ba.bindPopup(popup_9cb55d5ef88cc3c482f21819d4568909)
#         ;
#
#
#
#
#             var marker_0ca4658346186364bc57de57ba446d32 = L.marker(
#                 [5.33, -4.03],
#                 {}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
#
#
#         var popup_64d4f96e8cbf5dbeb231379268c8d08c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d62bf027184ca1a0b48e59d75cac4c3c = $(`&lt;div id=&quot;html_d62bf027184ca1a0b48e59d75cac4c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abidjan&lt;/div&gt;`)[0];
#                 popup_64d4f96e8cbf5dbeb231379268c8d08c.setContent(html_d62bf027184ca1a0b48e59d75cac4c3c);
#
#
#
#         marker_0ca4658346186364bc57de57ba446d32.bindPopup(popup_64d4f96e8cbf5dbeb231379268c8d08c)
#         ;
#
#
#
#
#             var marker_96c265740a887094438010b03932330d = L.marker(
#                 [45.52, -73.57],
#                 {}
#             ).addTo(map_57d2699ad2dc207ec3832312125246f5);
