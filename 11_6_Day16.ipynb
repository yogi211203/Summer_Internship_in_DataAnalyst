# %%
import numpy as np

# %% [markdown]
# ![population-variance.png](data:image/png;base64,...)

# %% [markdown]
# ## **Population Variance**

# %%
population = [ 5, 10, 15, 220, 25, 300, 35, 40, 45]

# %%
population
# Out:
# [5, 10, 15, 220, 25, 300, 35, 40, 45]

# %%
pop_mean = sum(population)/len(population)

# %%
pop_mean
# Out:
# 77.22222222222223

# %%
sq_pop_deviation = [(i-pop_mean)**2 for i in population]

# %%
sq_pop_deviation
# Out:
# [5216.04938271605,
#  4518.827160493828,
#  3871.6049382716055,
#  20385.49382716049,
#  2727.160493827161,
#  49629.93827160494,
#  1782.7160493827166,
#  1385.4938271604942,
#  1038.271604938272]

# %%
pop_variance = sum(sq_pop_deviation)/len(population)

# %%
print('Population Variance : {}'.format(round(pop_variance,2)))
# Out:
# Population Variance : 10061.73

# %% [markdown]
# ## **Sample Variance**

# %%
sample = np.arange(5,25,5)

# %%
sample
# Out:
# array([ 5, 10, 15, 20])

# %%
s_mean = sum(sample)/len(sample)

# %%
s_mean
# Out:
# 12.5

# %%
sq_s_deviation = [(i-s_mean)**2 for i in sample]

# %%
s_variance = sum(sq_s_deviation)/(len(sample) - 1)

# %%
print('Sample Variance : {}'.format(round(s_variance,2)))
# Out:
# Sample Variance : 41.67

# %% [markdown]
# ## **Standard Deviation**

# %%
import math

# %%
pop_variance
# Out:
# 10061.728395061727

# %%
std_dev = math.sqrt(pop_variance)

# %%
print('Standard Deviation : {}'.format(round(std_dev,2)))
# Out:
# Standard Deviation : 100.31

# %%
pop_mean
# Out:
# 77.22222222222223

# %% [markdown]
# ![population-standard-deviation-area-650-350.svg](data:image/svg+xml;base64,...)
